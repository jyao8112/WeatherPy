# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
import pandas as pd
import numpy as np
import requests
import time


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid=423160d06ea84b634174ef9038841d0f&units={units}&q="

city_data=[]
name=[]
cloudness=[]
country=[]
date=[]
humidity=[]
lat=[]
lng=[]
max_temp=[]
wind_speed=[]

print("Begining Data Retrieval")
print("---------------------------------------------------")
  
i=1
for city in cities:
        try:
            response = requests.get(query_url + city).json()
            if response['cod'] == 200:
                print("Processing Record " + str(i) + " of Set 1 | " + city)
                #city_data.append(response)
                name.append(response['name'])
                cloudness.append(response["clouds"]["all"])
                country.append(response['sys']['country'])
                date.append(response['sys']['sunrise'])
                humidity.append(response['main']['humidity'])
                lat.append(response['coord']['lat'])
                lng.append(response['coord']['lon'])
                wind_speed.append(response['wind']['speed'])
                max_temp.append(response['main']['temp_max'])
            else:
                print(f"City not found,skipping...")
        except:
            print(f"{response} Exception...")

        i=i+1
# Out:
# Begining Data Retrieval
# ---------------------------------------------------
# Processing Record 1 of Set 1 | newtonmore
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | mlyniv
# Processing Record 5 of Set 1 | nanortalik
# Processing Record 6 of Set 1 | hithadhoo
# City not found,skipping...
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | chokurdakh
# Processing Record 10 of Set 1 | egvekinot
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | longyearbyen
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | shache
# Processing Record 15 of Set 1 | comodoro rivadavia
# Processing Record 16 of Set 1 | vila velha
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | vardo
# Processing Record 19 of Set 1 | san patricio
# Processing Record 20 of Set 1 | bredasdorp
# City not found,skipping...
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | sao filipe
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | hirara
# City not found,skipping...
# Processing Record 27 of Set 1 | lompoc
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | lobatse
# Processing Record 30 of Set 1 | nakonde
# Processing Record 31 of Set 1 | carauari
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | khatanga
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | poum
# Processing Record 37 of Set 1 | nhulunbuy
# Processing Record 38 of Set 1 | nanakuli
# Processing Record 39 of Set 1 | jalu
# Processing Record 40 of Set 1 | chuy
# Processing Record 41 of Set 1 | port hardy
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | garwa
# Processing Record 44 of Set 1 | broken hill
# Processing Record 45 of Set 1 | kavaratti
# Processing Record 46 of Set 1 | pangody
# City not found,skipping...
# Processing Record 48 of Set 1 | butaritari
# Processing Record 49 of Set 1 | tuatapere
# Processing Record 50 of Set 1 | puerto carreno
# Processing Record 51 of Set 1 | smithers
# Processing Record 52 of Set 1 | ribeira grande
# Processing Record 53 of Set 1 | tiksi
# Processing Record 54 of Set 1 | beloslav
# City not found,skipping...
# Processing Record 56 of Set 1 | kapaa
# Processing Record 57 of Set 1 | hobyo
# Processing Record 58 of Set 1 | pacific grove
# Processing Record 59 of Set 1 | puerto ayora
# Processing Record 60 of Set 1 | new norfolk
# Processing Record 61 of Set 1 | tuktoyaktuk
# Processing Record 62 of Set 1 | sobolevo
# Processing Record 63 of Set 1 | vestmannaeyjar
# Processing Record 64 of Set 1 | navirai
# Processing Record 65 of Set 1 | tromso
# Processing Record 66 of Set 1 | hobart
# Processing Record 67 of Set 1 | pisco
# Processing Record 68 of Set 1 | jamestown
# Processing Record 69 of Set 1 | bonavista
# Processing Record 70 of Set 1 | yellowknife
# Processing Record 71 of Set 1 | faya
# Processing Record 72 of Set 1 | hilo
# Processing Record 73 of Set 1 | yumen
# Processing Record 74 of Set 1 | port lincoln
# City not found,skipping...
# Processing Record 76 of Set 1 | katsuura
# Processing Record 77 of Set 1 | ialibu
# Processing Record 78 of Set 1 | bayangol
# Processing Record 79 of Set 1 | bilma
# Processing Record 80 of Set 1 | adrar
# Processing Record 81 of Set 1 | siverek
# City not found,skipping...
# Processing Record 83 of Set 1 | srednekolymsk
# Processing Record 84 of Set 1 | santa maria
# Processing Record 85 of Set 1 | pattoki
# Processing Record 165 of Set 1 | san miguelito
# Processing Record 166 of Set 1 | santa fe
# City not found,skipping...
# Processing Record 168 of Set 1 | westport
# Processing Record 169 of Set 1 | aklavik
# Processing Record 170 of Set 1 | ikeda
# Processing Record 171 of Set 1 | margate
# Processing Record 172 of Set 1 | sitka
# Processing Record 173 of Set 1 | lillooet
# Processing Record 174 of Set 1 | souillac
# Processing Record 175 of Set 1 | mae hong son
# Processing Record 176 of Set 1 | tororo
# Processing Record 177 of Set 1 | russell
# Processing Record 178 of Set 1 | saint george
# Processing Record 179 of Set 1 | lokeren
# Processing Record 180 of Set 1 | rawlins
# Processing Record 181 of Set 1 | graham
# Processing Record 182 of Set 1 | aljezur
# Processing Record 183 of Set 1 | kologriv
# Processing Record 184 of Set 1 | chisec
# Processing Record 185 of Set 1 | mangrol
# Processing Record 186 of Set 1 | te anau
# Processing Record 187 of Set 1 | okitipupa
# Processing Record 188 of Set 1 | lorengau
# Processing Record 189 of Set 1 | telma
# Processing Record 190 of Set 1 | constitucion
# Processing Record 191 of Set 1 | ponta do sol
# Processing Record 192 of Set 1 | kasongo
# Processing Record 193 of Set 1 | taree
# Processing Record 194 of Set 1 | campbell river
# City not found,skipping...
# Processing Record 196 of Set 1 | nikolskoye
# Processing Record 197 of Set 1 | kaitangata
# Processing Record 198 of Set 1 | nioro
# City not found,skipping...
# Processing Record 200 of Set 1 | rincon
# Processing Record 201 of Set 1 | leningradskiy
# Processing Record 202 of Set 1 | lommel
# Processing Record 203 of Set 1 | yatou
# City not found,skipping...
# Processing Record 205 of Set 1 | buchanan
# Processing Record 206 of Set 1 | cayenne
# Processing Record 207 of Set 1 | buala
# Processing Record 208 of Set 1 | palmer
# Processing Record 209 of Set 1 | sept-iles
# Processing Record 210 of Set 1 | joshimath
# Processing Record 211 of Set 1 | upernavik
# City not found,skipping...
# Processing Record 213 of Set 1 | puerto ayacucho
# Processing Record 214 of Set 1 | sabinas hidalgo
# Processing Record 215 of Set 1 | airai
# Processing Record 216 of Set 1 | bowen
# Processing Record 217 of Set 1 | moose factory
# City not found,skipping...
# Processing Record 219 of Set 1 | atuona
# Processing Record 220 of Set 1 | cockburn town
# Processing Record 221 of Set 1 | verkhnyaya tishanka
# Processing Record 222 of Set 1 | la rioja
# Processing Record 223 of Set 1 | okato
# Processing Record 224 of Set 1 | saint-augustin
# Processing Record 225 of Set 1 | mangan
# Processing Record 226 of Set 1 | bilibino
# Processing Record 227 of Set 1 | hay river
# Processing Record 228 of Set 1 | vila franca do campo
# Processing Record 229 of Set 1 | lebu
# Processing Record 230 of Set 1 | pomabamba
# City not found,skipping...
# Processing Record 232 of Set 1 | salalah
# Processing Record 233 of Set 1 | evensk
# City not found,skipping...
# Processing Record 235 of Set 1 | khuzhir
# Processing Record 236 of Set 1 | dingle
# Processing Record 237 of Set 1 | yulara
# City not found,skipping...
# City not found,skipping...
# Processing Record 240 of Set 1 | oranjemund
# Processing Record 241 of Set 1 | ourem
# Processing Record 242 of Set 1 | codrington
# Processing Record 243 of Set 1 | rocha
# Processing Record 244 of Set 1 | richards bay
# Processing Record 245 of Set 1 | yeniseysk
# Processing Record 325 of Set 1 | bonanza
# Processing Record 326 of Set 1 | wewak
# Processing Record 327 of Set 1 | puerto madryn
# Processing Record 328 of Set 1 | lagoa
# Processing Record 329 of Set 1 | sharjah
# Processing Record 330 of Set 1 | sao felix do xingu
# Processing Record 331 of Set 1 | vostok
# Processing Record 332 of Set 1 | howard springs
# City not found,skipping...
# Processing Record 334 of Set 1 | katherine
# Processing Record 335 of Set 1 | nedumangad
# Processing Record 336 of Set 1 | sovetskiy
# Processing Record 337 of Set 1 | fairbanks
# Processing Record 338 of Set 1 | antsohihy
# Processing Record 339 of Set 1 | carmen
# Processing Record 340 of Set 1 | simao
# Processing Record 341 of Set 1 | wentzville
# Processing Record 342 of Set 1 | ossora
# Processing Record 343 of Set 1 | kapit
# Processing Record 344 of Set 1 | salt
# Processing Record 345 of Set 1 | vuktyl
# Processing Record 346 of Set 1 | saint-philippe
# Processing Record 347 of Set 1 | flinders
# Processing Record 348 of Set 1 | kruisfontein
# Processing Record 349 of Set 1 | jawhar
# Processing Record 350 of Set 1 | shush
# City not found,skipping...
# Processing Record 352 of Set 1 | ambilobe
# Processing Record 353 of Set 1 | qiongshan
# Processing Record 354 of Set 1 | klaksvik
# Processing Record 355 of Set 1 | ulaanbaatar
# City not found,skipping...
# Processing Record 357 of Set 1 | shingu
# Processing Record 358 of Set 1 | kayan
# Processing Record 359 of Set 1 | worland
# Processing Record 360 of Set 1 | gat
# Processing Record 361 of Set 1 | zhangjiakou
# Processing Record 362 of Set 1 | fagersta
# Processing Record 363 of Set 1 | dubbo
# Processing Record 364 of Set 1 | luderitz
# Processing Record 365 of Set 1 | foki
# Processing Record 366 of Set 1 | samdari
# Processing Record 367 of Set 1 | gamba
# Processing Record 368 of Set 1 | sambava
# Processing Record 369 of Set 1 | kangaatsiaq
# City not found,skipping...
# Processing Record 371 of Set 1 | guanica
# Processing Record 372 of Set 1 | bulri
# Processing Record 373 of Set 1 | grand gaube
# Processing Record 374 of Set 1 | fallon
# Processing Record 375 of Set 1 | isangel
# Processing Record 376 of Set 1 | atasu
# Processing Record 377 of Set 1 | alice springs
# Processing Record 378 of Set 1 | inyonga
# Processing Record 379 of Set 1 | ginda
# Processing Record 380 of Set 1 | touho
# Processing Record 381 of Set 1 | omsukchan
# Processing Record 382 of Set 1 | hinton
# Processing Record 383 of Set 1 | aswan
# Processing Record 384 of Set 1 | trat
# Processing Record 385 of Set 1 | mount gambier
# Processing Record 386 of Set 1 | urusha
# Processing Record 387 of Set 1 | mikhaylovka
# Processing Record 388 of Set 1 | oytal
# Processing Record 389 of Set 1 | drochia
# Processing Record 390 of Set 1 | chunoyar
# Processing Record 391 of Set 1 | pindi gheb
# Processing Record 392 of Set 1 | todos santos
# Processing Record 393 of Set 1 | vung tau
# Processing Record 394 of Set 1 | puerto leguizamo
# Processing Record 395 of Set 1 | kathmandu
# Processing Record 396 of Set 1 | mecca
# Processing Record 397 of Set 1 | coihaique
# Processing Record 398 of Set 1 | sao jose da coroa grande
# Processing Record 399 of Set 1 | salvador
# Processing Record 400 of Set 1 | mehamn
# Processing Record 401 of Set 1 | starobaltachevo
# Processing Record 402 of Set 1 | port-gentil
# Processing Record 403 of Set 1 | inirida
# Processing Record 404 of Set 1 | lodja
# City not found,skipping...
# Processing Record 406 of Set 1 | yar-sale
# Processing Record 407 of Set 1 | muhos
# Processing Record 408 of Set 1 | mezhdurechensk
# Processing Record 409 of Set 1 | mizan teferi
# Processing Record 410 of Set 1 | preobrazheniye
# Processing Record 411 of Set 1 | damietta
# Processing Record 412 of Set 1 | mana
# City not found,skipping...
# Processing Record 414 of Set 1 | vila do maio
# Processing Record 415 of Set 1 | kavieng
# City not found,skipping...
# Processing Record 417 of Set 1 | byron bay
# City not found,skipping...
# Processing Record 419 of Set 1 | west bay
# Processing Record 420 of Set 1 | necochea
# City not found,skipping...
# Processing Record 422 of Set 1 | tura
# Processing Record 423 of Set 1 | ust-karsk
# Processing Record 424 of Set 1 | kahului
# Processing Record 425 of Set 1 | iraquara
# Processing Record 426 of Set 1 | kitoy
# Processing Record 427 of Set 1 | hutchinson
# City not found,skipping...
# Processing Record 429 of Set 1 | tigzirt
# Processing Record 430 of Set 1 | port hedland
# Processing Record 431 of Set 1 | aksu
# Processing Record 432 of Set 1 | kokorevka
# Processing Record 433 of Set 1 | linxia
# City not found,skipping...
# Processing Record 435 of Set 1 | chagoda
# Processing Record 436 of Set 1 | teya
# Processing Record 437 of Set 1 | panzhihua
# Processing Record 438 of Set 1 | cururupu
# Processing Record 439 of Set 1 | kochki
# Processing Record 440 of Set 1 | rapid city
# Processing Record 441 of Set 1 | geraldton
# Processing Record 442 of Set 1 | zykovo
# Processing Record 443 of Set 1 | olga
# Processing Record 444 of Set 1 | huntington
# Processing Record 445 of Set 1 | healdsburg
# Processing Record 446 of Set 1 | ternate
# Processing Record 447 of Set 1 | ahuimanu
# Processing Record 448 of Set 1 | bathsheba
# Processing Record 449 of Set 1 | batagay-alyta
# Processing Record 450 of Set 1 | price
# Processing Record 451 of Set 1 | kokkola
# City not found,skipping...
# Processing Record 453 of Set 1 | botwood
# Processing Record 454 of Set 1 | raudeberg
# Processing Record 455 of Set 1 | mogadouro
# Processing Record 456 of Set 1 | bandarbeyla
# Processing Record 457 of Set 1 | balkanabat
# Processing Record 458 of Set 1 | banda aceh
# Processing Record 459 of Set 1 | bridgetown
# Processing Record 460 of Set 1 | maldonado
# Processing Record 461 of Set 1 | kenai
# Processing Record 462 of Set 1 | pahrump
# Processing Record 463 of Set 1 | fort worth
# City not found,skipping...
# Processing Record 465 of Set 1 | hambantota
# Processing Record 466 of Set 1 | alamosa
# Processing Record 467 of Set 1 | kichera
# Processing Record 468 of Set 1 | uray
# Processing Record 469 of Set 1 | cap malheureux
# Processing Record 470 of Set 1 | karasburg
# Processing Record 471 of Set 1 | lucapa
# Processing Record 472 of Set 1 | sabya
# Processing Record 473 of Set 1 | khandbari
# Processing Record 474 of Set 1 | mildura
# Processing Record 475 of Set 1 | zhigansk
# Processing Record 476 of Set 1 | colac
# Processing Record 477 of Set 1 | gisborne
# City not found,skipping...
# Processing Record 479 of Set 1 | chunskiy
# Processing Record 480 of Set 1 | barstow
# City not found,skipping...
# Processing Record 482 of Set 1 | dukat
# Processing Record 483 of Set 1 | hualmay
# Processing Record 484 of Set 1 | brenham
# Processing Record 485 of Set 1 | rapid valley
# Processing Record 486 of Set 1 | verkhnevilyuysk
# Processing Record 487 of Set 1 | veraval
# Processing Record 488 of Set 1 | bulgan
# Processing Record 489 of Set 1 | nein
# Processing Record 490 of Set 1 | campos belos
# Processing Record 491 of Set 1 | thinadhoo
# Processing Record 492 of Set 1 | nemuro
# Processing Record 493 of Set 1 | coquimbo
# Processing Record 494 of Set 1 | sinnamary
# Processing Record 495 of Set 1 | husavik
# Processing Record 496 of Set 1 | tamandare
# Processing Record 497 of Set 1 | kawalu
# Processing Record 498 of Set 1 | anshun
# Processing Record 499 of Set 1 | kailua
# Processing Record 500 of Set 1 | alihe
# Processing Record 501 of Set 1 | basco
# Processing Record 502 of Set 1 | amuntai
# Processing Record 503 of Set 1 | gerga
# Processing Record 504 of Set 1 | laizhou
# Processing Record 505 of Set 1 | salinopolis
# Processing Record 506 of Set 1 | newport
# Processing Record 507 of Set 1 | nabire
# Processing Record 508 of Set 1 | maceio
# Processing Record 509 of Set 1 | tutoia
# Processing Record 510 of Set 1 | singaparna
# Processing Record 511 of Set 1 | mokolo
# Processing Record 512 of Set 1 | dong hoi
# Processing Record 513 of Set 1 | nehe
# Processing Record 514 of Set 1 | san martin
# City not found,skipping...
# Processing Record 516 of Set 1 | okhotsk
# Processing Record 517 of Set 1 | hohhot
# Processing Record 518 of Set 1 | horana
# Processing Record 519 of Set 1 | coronado
# City not found,skipping...
# City not found,skipping...
# Processing Record 522 of Set 1 | praia
# Processing Record 523 of Set 1 | walvis bay
# Processing Record 524 of Set 1 | tynda
# Processing Record 525 of Set 1 | novikovo
# Processing Record 526 of Set 1 | redmond
# Processing Record 527 of Set 1 | de-kastri
# Processing Record 528 of Set 1 | hefei
# Processing Record 529 of Set 1 | frutal
# Processing Record 530 of Set 1 | kidal
# Processing Record 531 of Set 1 | artyom
# Processing Record 532 of Set 1 | anzhero-sudzhensk
# Processing Record 533 of Set 1 | mombetsu
# Processing Record 534 of Set 1 | pointe-noire
# Processing Record 535 of Set 1 | ancud
# Processing Record 536 of Set 1 | pingliang
# Processing Record 537 of Set 1 | batemans bay
# Processing Record 538 of Set 1 | uribia
# Processing Record 539 of Set 1 | solano
# Processing Record 540 of Set 1 | kampong thum
# Processing Record 541 of Set 1 | ulladulla
# Processing Record 542 of Set 1 | ambon
# Processing Record 543 of Set 1 | killam
# Processing Record 544 of Set 1 | agua dulce
# Processing Record 545 of Set 1 | los llanos de aridane
# Processing Record 546 of Set 1 | san isidro
# Processing Record 547 of Set 1 | bhum
# Processing Record 548 of Set 1 | poyarkovo
# Processing Record 549 of Set 1 | victor harbor
# Processing Record 550 of Set 1 | solginskiy
# Processing Record 551 of Set 1 | toshkivka
# Processing Record 552 of Set 1 | mishelevka
# Processing Record 553 of Set 1 | puerto escondido
# Processing Record 554 of Set 1 | takhtamygda
# City not found,skipping...
# City not found,skipping...
# Processing Record 557 of Set 1 | glodeni
# Processing Record 558 of Set 1 | goure
# Processing Record 559 of Set 1 | mocuba
# Processing Record 560 of Set 1 | cookeville
# Processing Record 561 of Set 1 | cheremukhovo
# Processing Record 562 of Set 1 | svetlogorsk
# Processing Record 563 of Set 1 | anadyr
# Processing Record 564 of Set 1 | clyde
# Processing Record 565 of Set 1 | san ramon
# Processing Record 566 of Set 1 | fukuma
# Processing Record 567 of Set 1 | ust-nera
# Processing Record 568 of Set 1 | katima mulilo
# Processing Record 569 of Set 1 | nan
# Processing Record 570 of Set 1 | wukari
# Processing Record 571 of Set 1 | zaozerne
# Processing Record 572 of Set 1 | the valley
# Processing Record 573 of Set 1 | sola
# Processing Record 574 of Set 1 | ballachulish
# Processing Record 575 of Set 1 | abnub
# Processing Record 576 of Set 1 | guerrero negro
# Processing Record 577 of Set 1 | soyo
# City not found,skipping...
# Processing Record 579 of Set 1 | mareeba
# Processing Record 580 of Set 1 | fort nelson
# Processing Record 581 of Set 1 | luena
# Processing Record 582 of Set 1 | bathurst
# Processing Record 583 of Set 1 | jolalpan
# Processing Record 584 of Set 1 | tual
# Processing Record 585 of Set 1 | general roca
# Processing Record 586 of Set 1 | griffith
# Processing Record 587 of Set 1 | haines junction
# Processing Record 588 of Set 1 | kharp
# Processing Record 589 of Set 1 | helong
# Processing Record 590 of Set 1 | riosucio
# Processing Record 591 of Set 1 | manokwari
# Processing Record 592 of Set 1 | teodoro sampaio
# Processing Record 593 of Set 1 | alekseyevka
# Processing Record 594 of Set 1 | borogontsy
# Processing Record 595 of Set 1 | marrakesh
# Processing Record 596 of Set 1 | weligama
# Processing Record 597 of Set 1 | payo
# Processing Record 598 of Set 1 | dashitou
# Processing Record 599 of Set 1 | huarmey
# Processing Record 600 of Set 1 | boralday
# Processing Record 601 of Set 1 | savantvadi
# City not found,skipping...
# Processing Record 603 of Set 1 | katobu

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#city_data_df=pd.DataFrame(city_data)

city_data_df = pd.DataFrame(
    {'City': name,
     'Cloudiness': cloudness,
     'Country': country,
     'Date': date,
     'Humidity': humidity,
     'Lat': lat,
     'Lng': lng,
     'Max Temp': max_temp,
     'Wind Speed': wind_speed
    })

city_data_df.to_csv("city_data.csv",index=True)
city_data_df.count()
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lat, max_temp  , marker="o", facecolors="darkblue", edgecolors="black",
            alpha=0.75)
plt.grid()
plt.title("City Latitude vs. Max Temperature(%s)"%time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.savefig("CityLat_vs_maxTemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lat, humidity  , marker="o", facecolors="darkblue", edgecolors="black",
            alpha=0.75)
plt.grid()
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")

plt.savefig("CityLat_vs_humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat, cloudness , marker="o", facecolors="darkblue", edgecolors="black",
            alpha=0.75)
plt.grid()
plt.title("City Latitude vs Cloudiness(%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")

plt.savefig("CityLat_vs_cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat, wind_speed , marker="o", facecolors="darkblue", edgecolors="black",
            alpha=0.75)
plt.grid()
plt.title("City Latitude vs Wind Speed(%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.savefig("CityLat_vs_windspeed.png")
plt.show()

# %% [markdown]
# ### Analysis

# %% [markdown]
# #### Observed Trend 1:  City closed to equatorial region has the higest temperature
# #### Observed Trend 2:  City closed to Poles have higher relative humidity
# #### Observed Trend 3:  City Cloudness is similar along the different Latitude
# #### Observed Trend 4:  City Wind Speed is also similar along the different Latitude
